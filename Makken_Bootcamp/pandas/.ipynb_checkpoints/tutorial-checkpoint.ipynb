# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# ### This is a brief tutorial on how to manipulate data using pandas

# %% [markdown]
# *The car model dataset is a comprehensive collection of information about cars. It includes information about the car's specifications, such as horsepower, torque, transmission type, drivetrain, fuel economy, number of doors, price, model year range, body type, engine type, and number of cylinders. The dataset also includes information about the car's history, such as the year it was first released, the number of units sold, and the average price.*
#
# *Data source: https://www.kaggle.com/datasets/peshimaammuzammil/2023-car-model-dataset-all-data-you-need?resource=download*

# %% [markdown]
# **Import the Pandas library into your Jupyter Notebook using the following import statement:**

# %%
import pandas as pd

# %% [markdown]
# **Pandas provides the read_csv() function, which can load data from a CSV file :**

# %%
data = pd.read_csv('Car_Models.csv')

# %% [markdown]
# **After loading the data, let's explore it to understand its structure and contents. Here are some useful functions:**

# %%
data.head()
# Out:
#    Company          Model Horsepower     Torque  Transmission Type Drivetrain  \
# 0  Ferrari  812 Superfast     789 hp  530 lb-ft  7-speed automatic        RWD
# 1  Ferrari     F8 Tributo     710 hp  568 lb-ft  7-speed automatic        RWD
# 2  Ferrari           Roma     611 hp  560 lb-ft  8-speed automatic        RWD
# 3  Ferrari    Portofino M     612 hp  561 lb-ft  8-speed automatic        RWD
# 4  Ferrari  SF90 Stradale     986 hp  590 lb-ft  8-speed automatic        AWD
#
#         Fuel Economy Number of Doors     Price Model Year Range    Body Type  \
# 0          13/20 mpg               2  $366,712   2018 - Present        Coupe
# 1          15/19 mpg               2  $276,550   2020 - Present        Coupe
# 2          16/24 mpg               2  $218,750   2021 - Present        Coupe
# 3          16/22 mpg               2  $254,475   2021 - Present  Convertible
# 4  18 mpg (combined)               2  $625,000   2020 - Present        Coupe
#
#   Engine Type Number of Cylinders
# 0    6.5L V12                  12
# 1     3.9L V8                   8
# 2     3.9L V8                   8
# 3     3.9L V8                   8
# 4     4.0L V8                   8

# %% [markdown]
# **If we want to grab the columns names:**

# %%
data.columns
# Out:
# Index(['Company', 'Model', 'Horsepower', 'Torque', 'Transmission Type',
#        'Drivetrain', 'Fuel Economy', 'Number of Doors', 'Price',
#        'Model Year Range', 'Body Type', 'Engine Type', 'Number of Cylinders'],
#       dtype='object')

# %% [markdown]
# **Let's say we want to filter the data to include only rows where the 'Company' column is equal to 'Honda':**

# %%
data[data['Company'] == 'Honda']
# Out:
#     Company    Model Horsepower     Torque   Transmission Type  \
# 371   Honda   Accord     192 hp  192 lb-ft  10-speed automatic
# 372   Honda    Civic     158 hp  138 lb-ft       CVT automatic
# 373   Honda     CR-V     190 hp  179 lb-ft  10-speed automatic
# 374   Honda     HR-V     158 hp  138 lb-ft       CVT automatic
# 375   Honda  Odyssey     280 hp  262 lb-ft  10-speed automatic
# 376   Honda    Pilot     280 hp  262 lb-ft   9-speed automatic
# 377   Honda  Insight     151 hp  134 lb-ft       CVT automatic
# 378   Honda      NSX     573 hp  492 lb-ft   9-speed automatic
# 379   Honda    S2000     240 hp  162 lb-ft      6-speed manual
#
#                                Drivetrain          Fuel Economy  \
# 371                     Front-wheel drive  27 city / 37 highway
# 372                     Front-wheel drive  31 city / 40 highway
# 373  Front-wheel drive or all-wheel drive  27 city / 32 highway
# 374                     Front-wheel drive  28 city / 32 highway
# 375                     Front-wheel drive  19 city / 28 highway
# 376  Front-wheel drive or all-wheel drive  19 city / 26 highway
# 377                     Front-wheel drive  49 city / 47 highway
# 378                      Rear-wheel drive  21 city / 28 highway
# 379                      Rear-wheel drive  20 city / 28 highway
#
#     Number of Doors                 Price Model Year Range   Body Type  \
# 371               4   Starting at $24,770     2021-present       Sedan
# 372               4   Starting at $21,700     2022-present       Sedan
# 373               5   Starting at $25,295     2023-present         SUV
# 374               5   Starting at $21,700     2023-present         SUV
# 375               8   Starting at $31,470     2023-present     Minivan
# 376               8   Starting at $36,295     2023-present         SUV
# 377               5   Starting at $23,695     2023-present      Hybrid
# 378               2  Starting at $156,000     2016-present  Sports car
# 379               2   Starting at $31,995        1999-2009  Sports car
#
#     Engine Type Number of Cylinders
# 371  4-cylinder                   4
# 372  4-cylinder                   4
# 373  4-cylinder                   4
# 374  4-cylinder                   4
# 375          V6                   6
# 376          V6                   6
# 377  4-cylinder                   4
# 378          V6                   6
# 379  4-cylinder                   4

# %% [markdown]
# **We can get a brief describtion of the dataset :**

# %%
data.describe()
# Out:
#           Company Model Horsepower     Torque  Transmission Type  \
# count         404   404        404        404                404
# unique         62   374        232        205                 68
# top     Chevrolet   Zoe     148 hp  184 lb-ft  8-speed automatic
# freq           20     2         12         19                 81
#
#                Drivetrain Fuel Economy Number of Doors                Price  \
# count                 404          399             404                  398
# unique                 22          250              22                  323
# top     Front-wheel drive        9 mpg               5  Starting at $32,990
# freq                   79           10             121                    5
#
#        Model Year Range Body Type Engine Type Number of Cylinders
# count               403       403         403                 402
# unique              125        31          94                  23
# top           2023-2024       SUV  4-cylinder                   4
# freq                 85       135          93                 163
